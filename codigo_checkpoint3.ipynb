# %% [markdown]
# <a href="https://colab.research.google.com/github/SamG1002/PythonFiap/blob/main/codigo_checkpoint3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Checkpoint 3

# %% [markdown]
# ## Carregar módulos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#calculo
import sympy as sp

# %% [markdown]
# ## Carregar dados

# %%
path = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
path_dead =  'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'

# %%
dados_paises_covid = pd.read_csv(path)
dados_paises_covid_dead = pd.read_csv(path_dead)

# %%
dados_paises_covid
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 280            NaN    West Bank and Gaza  31.952200   35.233200        0
# 281            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 282            NaN                 Yemen  15.552727   48.516388        0
# 283            NaN                Zambia -13.133897   27.849332        0
# 284            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/17/22  5/18/22  \
# ...

# %% [markdown]
# ## Ajustes

# %% [markdown]
# - Nomes das colunas

# %%
dados_paises_covid.rename(columns={"Province/State": "province", 
                                   "Country/Region": "country"}, 
                          inplace=True)

# %%
dados_paises_covid_dead.rename(columns={"Province/State": "province", 
                                        "Country/Region": "country"}, 
                               inplace=True)

# %%
dados_paises_covid_dead.columns
# Out:
# Index(['province', 'country', 'Lat', 'Long', '1/22/20', '1/23/20', '1/24/20',
#        '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '5/17/22', '5/18/22', '5/19/22', '5/20/22', '5/21/22', '5/22/22',
#        '5/23/22', '5/24/22', '5/25/22', '5/26/22'],
#       dtype='object', length=860)

# %% [markdown]
# - Reajustar dados

# %%
dados_paises_covid = dados_paises_covid.melt(id_vars=['province', 'country', 'Lat', 'Long'], 
                                             var_name = 'date', 
                                             value_name = 'infected')

# %%
dados_paises_covid_dead = dados_paises_covid_dead.melt(id_vars=['province', 'country', 'Lat', 'Long'], 
                                                       var_name = 'date', 
                                                       value_name = 'dead')

# %%
dados_paises_covid_dead.tail()
# Out:
#        province               country        Lat        Long     date  dead
# 243955      NaN    West Bank and Gaza  31.952200   35.233200  5/26/22  5660
# 243956      NaN  Winter Olympics 2022  39.904200  116.407400  5/26/22     0
# 243957      NaN                 Yemen  15.552727   48.516388  5/26/22  2149
# 243958      NaN                Zambia -13.133897   27.849332  5/26/22  3985
# 243959      NaN              Zimbabwe -19.015438   29.154857  5/26/22  5498

# %%
dados_paises_covid_dead.dtypes
# Out:
# province     object
# country      object
# Lat         float64
# Long        float64
# date         object
# dead          int64
# dtype: object

# %% [markdown]
# - Ajustar datas

# %%
dados_paises_covid['date'] = pd.to_datetime(dados_paises_covid['date'], 
                                            infer_datetime_format='True')

# %%
dados_paises_covid_dead['date'] = pd.to_datetime(dados_paises_covid_dead['date'], 
                                                 infer_datetime_format='True')

# %%
dados_paises_covid.tail()
# Out:
#        province               country        Lat        Long       date  \
# 243955      NaN    West Bank and Gaza  31.952200   35.233200 2022-05-26
# 243956      NaN  Winter Olympics 2022  39.904200  116.407400 2022-05-26
# 243957      NaN                 Yemen  15.552727   48.516388 2022-05-26
# 243958      NaN                Zambia -13.133897   27.849332 2022-05-26
# 243959      NaN              Zimbabwe -19.015438   29.154857 2022-05-26
#
#         infected
# 243955    657573
# 243956       535
# 243957     11819
# 243958    321399
# 243959    251646

# %%
dados_paises_covid_dead.tail()
# Out:
#        province               country        Lat        Long       date  dead
# 243955      NaN    West Bank and Gaza  31.952200   35.233200 2022-05-26  5660
# 243956      NaN  Winter Olympics 2022  39.904200  116.407400 2022-05-26     0
# 243957      NaN                 Yemen  15.552727   48.516388 2022-05-26  2149
# 243958      NaN                Zambia -13.133897   27.849332 2022-05-26  3985
# 243959      NaN              Zimbabwe -19.015438   29.154857 2022-05-26  5498

# %%
dados_paises_covid_dead.dtypes
# Out:
# province            object
# country             object
# Lat                float64
# Long               float64
# date        datetime64[ns]
# dead                 int64
# dtype: object

# %% [markdown]
# - Combinar os datasets

# %%
dados_paises_covid.shape
# Out:
# (243960, 6)

# %%
dados_paises_covid_dead.shape
# Out:
# (243960, 6)

# %%
dados_covid = pd.merge(dados_paises_covid, dados_paises_covid_dead, 
                       on = ['province', 'country',	'Lat',	'Long',	'date'], 
                       how = 'inner')

# %%
dados_covid.tail()
# Out:
#        province               country        Lat        Long       date  \
# 243955      NaN    West Bank and Gaza  31.952200   35.233200 2022-05-26
# 243956      NaN  Winter Olympics 2022  39.904200  116.407400 2022-05-26
# 243957      NaN                 Yemen  15.552727   48.516388 2022-05-26
# 243958      NaN                Zambia -13.133897   27.849332 2022-05-26
# 243959      NaN              Zimbabwe -19.015438   29.154857 2022-05-26
#
#         infected  dead
# 243955    657573  5660
# 243956       535     0
# 243957     11819  2149
# 243958    321399  3985
# 243959    251646  5498

# %%
dados_covid.shape
# Out:
# (243960, 7)

# %% [markdown]
# ## Aqui começa o trabalho

# %% [markdown]
# ***1 – Agrupar a soma de infectados e mortes de todos os países por data.***

# %%
soma = dados_covid.groupby('date')[['infected','dead']].sum()
soma
# Out:
#              infected     dead
# date
# 2020-01-22        557       17
# 2020-01-23        657       18
# 2020-01-24        944       26
# 2020-01-25       1437       42
# 2020-01-26       2120       56
# ...               ...      ...
# 2022-05-22  525612127  6277245
# 2022-05-23  526096866  6278676
# 2022-05-24  526708614  6280424
# 2022-05-25  527351268  6283065
# 2022-05-26  527840775  6284533
#
# [856 rows x 2 columns]

# %% [markdown]
# ***2 – Criar duas colunas contendo a variação bruta diária de infectados e mortos. Recomenda-se
# realizar esta tarefa conforme o seguinte exemplo:***

# %%
difMortesXInfectados = dados_covid[['dead', 'infected']] = dados_covid.groupby('country')[['dead', 'infected']].diff()
dados_covid_top = dados_covid.assign(VarMortos = difMortesXInfectados['dead'], VarInfectados = difMortesXInfectados['infected'])
dados_covid_top[['country', 'date', 'dead', 'infected', 'VarMortos', 'VarInfectados']]
# Out:
#                      country       date  dead  infected  VarMortos  \
# 0                Afghanistan 2020-01-22   NaN       NaN        NaN
# 1                    Albania 2020-01-22   NaN       NaN        NaN
# 2                    Algeria 2020-01-22   NaN       NaN        NaN
# 3                    Andorra 2020-01-22   NaN       NaN        NaN
# 4                     Angola 2020-01-22   NaN       NaN        NaN
# ...                      ...        ...   ...       ...        ...
# 243955    West Bank and Gaza 2022-05-26   0.0       0.0        0.0
# 243956  Winter Olympics 2022 2022-05-26   0.0       0.0        0.0
# 243957                 Yemen 2022-05-26   0.0       0.0        0.0
# 243958                Zambia 2022-05-26   0.0      57.0        0.0
# 243959              Zimbabwe 2022-05-26   2.0     418.0        2.0
#
#         VarInfectados
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...

# %% [markdown]
# ***3 – Criar duas colunas contendo a variação percentual diária de infectados e mortos.
# Recomenda-se realizar esta tarefa conforme o seguinte exemplo:***

# %%
InfecDiario = dados_covid[['infected', 'dead']] = dados_covid.groupby('date')[['infected', 'dead']].pct_change()
dados_covid_top = dados_covid_top.assign(VarPercDiarioMortos = InfecDiario['dead'], VarPercDiarioInfectados = InfecDiario['infected'])
dados_covid_top[['country', 'date', 'dead', 'infected', 'VarMortos', 'VarInfectados', 'VarPercDiarioMortos', 'VarPercDiarioInfectados']]
# Out:
#                      country       date  dead  infected  VarMortos  \
# 0                Afghanistan 2020-01-22   NaN       NaN        NaN
# 1                    Albania 2020-01-22   NaN       NaN        NaN
# 2                    Algeria 2020-01-22   NaN       NaN        NaN
# 3                    Andorra 2020-01-22   NaN       NaN        NaN
# 4                     Angola 2020-01-22   NaN       NaN        NaN
# ...                      ...        ...   ...       ...        ...
# 243955    West Bank and Gaza 2022-05-26   0.0       0.0        0.0
# 243956  Winter Olympics 2022 2022-05-26   0.0       0.0        0.0
# 243957                 Yemen 2022-05-26   0.0       0.0        0.0
# 243958                Zambia 2022-05-26   0.0     -17.0        0.0
# 243959              Zimbabwe 2022-05-26   2.0     119.0        2.0
#
#         VarInfectados  VarPercDiarioMortos  VarPercDiarioInfectados
# 0                 NaN                  NaN                      NaN
# ...

# %% [markdown]
# ***4 – Filtrar os países: Brasil, Estados Unidos, Itália e Canadá. (Problema secundário: como você
# resolverá o problema dos valores “NaN” e alguns valores “inf”? Dica: existem algumas funções
# que podem auxiliar, como dropna, fillna, replace. Escolher o que melhor atender a solução.)***

# %%
dados_covid_top[(dados_covid_top['country']=='Brazil') | (dados_covid_top['country']== 'Italy') | (dados_covid_top['country']== 'Canada') | (dados_covid_top['country']== 'US')].fillna('Não informado')
dados_covid_top = dados_covid_top.dropna()
dados_covid_top
# Out:
#                                             province         country  \
# 10                                   New South Wales       Australia
# 11                                Northern Territory       Australia
# 12                                        Queensland       Australia
# 13                                   South Australia       Australia
# 14                                          Tasmania       Australia
# ...                                              ...             ...
# 243944                                   Isle of Man  United Kingdom
# 243945                                        Jersey  United Kingdom
# 243946                                    Montserrat  United Kingdom
# 243947  Saint Helena, Ascension and Tristan da Cunha  United Kingdom
# 243948                      Turks and Caicos Islands  United Kingdom
#
#               Lat        Long       date  infected   dead  VarMortos  \
# ...

# %% [markdown]
# ***5 – Obter a média mensal da variação bruta de infectados e mortos para cada país. Descreva os
# resultados. (Dica: transformar a data que está no formato “yyyy-mm-dd” para ano-mês, isto é,
# “yyyy-mm”, pesquisar o comando “df['date'].dt.to_period('M')”)***

# %%
dados_covid_top['etad'] = dados_covid_top['date'].dt.to_period('M')
dados_covid_top = dados_covid_top.drop(columns=['date'])
dados_covid_top = dados_covid_top.rename(columns={'etad': 'date'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dados_covid_top = dados_covid_top[['dead', 'infected']] = dados_covid_top.groupby(['country','date'])[['VarMortos', 'VarInfectados']].mean()
dados_covid_top
# Out:
#                            VarMortos  VarInfectados          dead  \
# country        date
# Australia      2020-01      0.000000   0.000000e+00      0.000000
#                2020-02      0.000000   8.620690e-03      0.000000
#                2020-03      0.008065   1.459677e+00      0.008065
#                2020-04      0.025000   7.791667e-01      0.025000
#                2020-05      0.004032   1.532258e-01      0.004032
# ...                              ...            ...           ...
# United Kingdom 2022-01 -11679.995037  -1.152445e+06 -11679.995037
#                2022-02 -12261.717033  -1.402230e+06 -12261.717033
#                2022-03 -12547.565757  -1.527899e+06 -12547.565757
#                2022-04 -13124.343590  -1.667424e+06 -13124.343590
#                2022-05 -13601.642012  -1.704524e+06 -13601.642012
#
#                             infected
# country        date
# Australia      2020-01  0.000000e+00
#                2020-02  8.620690e-03
# ...

# %% [markdown]
# ***6 – Obter a média mensal da variação percentual de infectados e mortos para cada país.
# Descreva os resultados.***

# %%
media = sp.diff(dados_covid_top.groupby(['date', 'country'])[['dead', 'infected']].mean())
media
# Out:
#                                 dead      infected
# date    country
# 2020-01 Australia                NaN           NaN
#         Canada              0.000000  0.000000e+00
#         China               0.000000  1.638298e+00
#         Denmark             0.000000 -1.638298e+00
#         France              0.000000 -2.293578e-01
# ...                              ...           ...
# 2022-05 Denmark         -3120.826923 -1.529505e+06
#         France          -9960.260490 -1.014796e+06
#         Netherlands      7526.212413  5.370763e+05
#         New Zealand      4666.682692  1.006257e+06
#         United Kingdom -12713.449704 -6.760638e+05
#
# [232 rows x 2 columns]

# %% [markdown]
# **7 – Gerar os seguintes gráficos:**
#
#
#
#
# ***a) Gráfico de barras contendo a evolução média mensal da variação BRUTA de infectados
# para Brasil. E.U.A e Itália (Um gráfico para cada país separadamente)***

# %%
ax = dados_covid.plot.bar(x = 'dead', y = 'date')
plt.xlabel('dead')
plt.ylabel('date')
plt.title('Comparativo Brasil  x EUA')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-e684a17dde18> in <module>()
# ----> 1 ax = dados_covid.plot.bar(x = 'dead', y = 'date')
#       2 plt.xlabel('dead')
#       3 plt.ylabel('date')
#       4 plt.title('Comparativo Brasil  x EUA')
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1128         other axis represents a measured value.
#    1129         """
# -> 1130         return self(kind="bar", x=x, y=y, **kwargs)
#    1131
#    1132     @Appender(
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ...

# %% [markdown]
# **b) Gráfico de linhas contendo a evolução média mensal da variação PERCENTUAL de
# mortes para Brasil. E.U.A e Itália (Um gráfico para cada país separadamente)**
